# %%
# %matplotlib inline

from blockchain import statistics
import requests
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
import matplotlib
import numpy as np

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# <h3> Glossary </h3>
# <p> DT = DAILY TRANSACTIONS</p>
# <P> DUA = DAILY UNIQUE ADRESSES </P>
# <P> DTV = DAILY TRANSACTION VOLUME </P>
# <P> DDTV = DAILY DOLLAR TRANSACTION VOLUME </P>
# <p> BIC = BITCOIN IN CIRCULATION </p>
# <p> MP = MARKET PRICE </p>

# %%
DT_get = requests.get("https://blockchain.info/charts/n-transactions?timespan=all&format=json")
DUA_get = requests.get("https://blockchain.info/charts/n-unique-addresses?timespan=all&format=json")
DTV_get = requests.get("https://blockchain.info/charts/estimated-transaction-volume?timespan=all&format=json")
DDTV_get = requests.get("https://blockchain.info/charts/estimated-transaction-volume-usd?timespan=all&format=json")
BIC_get = requests.get("https://blockchain.info/charts/total-bitcoins?timespan=all&format=json")
MP_get = requests.get("https://blockchain.info/charts/market-price?timespan=all&format=json")

# %%
DT_json = DT_get.json()
DUA_json = DUA_get.json()
DTV_json = DTV_get.json()
DDTV_json = DDTV_get.json()
BIC_json = BIC_get.json()
MP_json = MP_get.json()

# %%
type(DT_json)
#Prep_y = pd.DataFrame(list(x.values())[1])
# Out:
# dict

# %%
DT = pd.DataFrame(list(DT_json.values())[4])
DT.columns = ['Date', 'Transactions']

DUA = pd.DataFrame(list(DUA_json.values())[4])
DUA.columns = ['Date', 'UniqueAdresses']
DUA = DUA.drop('Date', axis=1)

DTV = pd.DataFrame(list(DTV_json.values())[4])
DTV.columns = ['Date', 'TransactionVolume']
DTV = DTV.drop('Date', axis=1)

DDTV = pd.DataFrame(list(DDTV_json.values())[4])
DDTV.columns = ['Date', 'DailyDollarTransactionVolume']
DDTV = DDTV.drop('Date', axis=1)

BIC = pd.DataFrame(list(BIC_json.values())[4])
BIC.columns = ['Date', 'BitCoinInCirculation']
BIC = BIC.drop('Date', axis=1)

MP = pd.DataFrame(list(MP_json.values())[4])
MP.columns = ['Date', 'MarketPrice']
MP = MP.drop('Date', axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-670eb77c41c4> in <module>()
#       2 DT.columns = ['Date', 'Transactions']
#       3
# ----> 4 DUA = pd.DataFrame(list(DUA_json.values().set_printoptions(suppress=True))[4])
#       5 DUA.columns = ['Date', 'UniqueAdresses']
#       6 DUA = DUA.drop('Date', axis=1)
#
# AttributeError: 'dict_values' object has no attribute 'set_printoptions'

# %%
DataSet = pd.concat([DT, DUA], axis=1)
DataSet = pd.concat([DataSet, DTV], axis=1)
DataSet = pd.concat([DataSet, DDTV], axis=1)
DataSet = pd.concat([DataSet, BIC], axis=1)
DataSet = pd.concat([DataSet, MP], axis=1)
DataSet['Date'] = pd.to_datetime(DataSet['Date'],unit='s')
DataSet
# Out:
#            Date  Transactions  UniqueAdresses  TransactionVolume  \
# 0    2009-01-03             1               1              0.000
# 1    2009-01-05             0               0              0.000
# 2    2009-01-07             0               0              0.000
# 3    2009-01-09            14              14              0.000
# 4    2009-01-11           106             106              0.000
# 5    2009-01-13           116             117             10.000
# 6    2009-01-15           136             136            414.000
# 7    2009-01-17           109             109            100.000
# 8    2009-01-19           120             120            150.000
# 9    2009-01-21           115             115            500.000
# 10   2009-01-23            68              68            150.000
# 11   2009-01-25           195             195             50.000
# 12   2009-01-27           105             105           1150.000
# 13   2009-01-29           122             122              0.000
# 14   2009-01-31           129             129              0.000
# 1518                 403324576.010          16297612.500     1345.350
# 1519                 358298055.710          16301475.000     1334.970
# 1520                 442436010.500          16305237.500     1417.170
# 1521                 478643852.400          16308862.500     1507.570
# 1522                 572492738.290          16312575.000     1533.330
# 1523                 425425969.140          16316762.500     1535.860
# 1524                 761394965.370          16320950.000     1721.280
# 1525                 663588561.070          16324487.500     1820.990
# 1526                 444311275.690          16328387.500     1771.920
# 1527                 691417744.070          16332562.500     1723.120
# 1528                 937290192.570          16336150.000     1807.480
# 1529                 858596952.490          16339975.000     1961.520
# 1530                 545513367.880          16343875.000     2046.530
# 1531                1026598216.660          16347800.000     2287.710
# 1532                1209302552.270          16351762.500     2387.200
# 1533                 646375171.120          16355775.000     2014.050
# 1534                 574153810.840          16359725.000     2275.930
# 1535                 853819146.380          16364012.500     2285.930
# 1536                 726398967.480          16367962.500     2446.140
# 1537                 627567197.390          16372375.000     2516.170
# 1538                 886338620.290          16376312.500     2883.310
# 1539                 810352769.000          16380437.500     2792.990
# 1540                 671075205.240          16384087.500     2845.370
# 1541                 839906528.510          16387750.000     2657.670
# 1542                 753304915.370          16391262.500     2447.040
#
# [1543 rows x 7 columns]

# %%
DataSet = DataSet.drop('DailyDollarTransactionVolume', axis = 1)

# %%
DataSet.describe()
# Out:
#        Transactions  UniqueAdresses  TransactionVolume  BitCoinInCirculation  \
# count      1543.000        1543.000           1543.000              1543.000
# mean      75227.056      136678.079         173057.827           9682595.139
# std       90476.314      167580.031         245540.687           5123478.608
# min           0.000           0.000              0.000                50.000
# 25%        1854.000        2427.000          49681.500           5394200.000
# 50%       46797.000       46589.000         142835.000          10949700.000
# 75%      105966.500      223387.500         240915.500          14127412.500
# max      367710.000      687290.000        5313161.000          16391262.500
#
#        MarketPrice
# count     1543.000
# mean       258.899
# std        379.783
# min          0.000
# 25%          0.790
# 50%         70.940
# 75%        427.035
# max       2883.310

# %%
DataSet.corr()
# Out:
#                       Transactions  UniqueAdresses  TransactionVolume  \
# Transactions                 1.000           0.987              0.294
# UniqueAdresses               0.987           1.000              0.280
# TransactionVolume            0.294           0.280              1.000
# BitCoinInCirculation         0.798           0.801              0.351
# MarketPrice                  0.798           0.824              0.182
#
#                       BitCoinInCirculation  MarketPrice
# Transactions                         0.798        0.798
# UniqueAdresses                       0.801        0.824
# TransactionVolume                    0.351        0.182
# BitCoinInCirculation                 1.000        0.659
# MarketPrice                          0.659        1.000

# %% [markdown]
# <h3> Transactions vs MarketPrice </h3>

# %%
plt.plot(DataSet.Transactions, DataSet.MarketPrice, 'ro')
plt.ylabel('Price (USD)')
plt.xlabel('Transactions Per DAY')
plt.show()

# %% [markdown]
# <h3> UniqueAdresses vs MarketPrice</h3>

# %%
plt.plot(DataSet.UniqueAdresses,DataSet.MarketPrice, 'ro')
plt.ylabel('Price (USD)')
plt.xlabel('UniqueAdresses')
plt.show()

# %% [markdown]
# <h3> TransactionVolume vs MarketPrice</h3>

# %%
plt.plot(DataSet.TransactionVolume, DataSet.MarketPrice, 'ro')
plt.ylabel('Price (USD)')
plt.xlabel('TransactionVolume')
plt.show()

# %% [markdown]
# <h3> BitCoinInCirculation vs MarketPrice</h3>

# %%
plt.plot(DataSet.BitCoinInCirculation, DataSet.MarketPrice, 'ro')
plt.ylabel('Price (USD)')
plt.xlabel('BitCoinInCirculation')
plt.show()
